# %%
#Load Libraries
# %matplotlib inline
import pandas as pd
# import swat
import numpy as np
#import matplotlib.pyplot as pit
import seaborn as sns
from sklearn.manifold import TSNE
import matplotlib
#import numpy as np
import matplotlib.pyplot as plt
# from time import timeline
#import plotly.plotly as py
#import hypertools as hyp

# %%
# #Load Libraries
# import pandas as pd
# # import swat
# import numpy as np
# import matplotlib.pyplot as pit
# import seaborn as sns
# from sklearn.manifold import TSNE
# # from time import timeline


#Read in Data
data = pd.read_csv('Downloads/Documents/BM_AM_180808_RegVirtStackSlices-Table 1.csv')

#print(data)

new_data = data[["Islet1","Pax6","CABP5","SCGN","CAVIII","Rec","Calb","Parv"]]

#print(new_data)

# display(data.shape)

# data_cas = conn.upload_frame(data, casout=dict(name='data_set', replace=True))

#head(data)

#tsne = TSNE(n_components = 2, n_iter = 1000, perplexity = 30)


#plt.plot(range(10))



# tsne_run = TSNE(n_components = 2, n_iter = 1000, perplexity = 30).fit_transform(new_data)

# #tsne_run = tsne.fit_transform(new_data)
# colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'w', 'orange', 'purple'
# for i, c, label in zip(target_ids, colors, digits.target_names):
#     plt.scatter(tsne_run[y == i, 0], tsne_run[y == i, 1], c=c, label=label)
# plt.legend()
# plt.show()

# plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
# text(tsne_run, labels = rownames(dat))
# hyp.show()
# #text(tsne_run, labels = rownames(dat3))

# %%
# #1000 iterations
# tsne = TSNE(n_components = 2, n_iter = 1000, perplexity = 30)
# tsne_run = tsne.fit_transform(new_data)
# #plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
# plt.plot(tsne_run)

# %%
# tsne = TSNE(n_components = 2, n_iter = 1000, perplexity = 30)
# tsne_run = tsne.fit_transform(new_data)
# # plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
# plt.ylabel('coord2')
# plt.xlabel('coord1')
# plt.plot(tsne_run)
# plt.show()
# # plt.plot(tsne_run)
# # colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'w', 'orange', 'purple'
# # for i, c, label in zip(target_ids, colors, digits.target_names):
# #     plt.scatter(tsne_run[y == i, 0], tsne_run[y == i, 1], c=c, label=label)

# # fig, ax = plt.subplots()

# # colors = {'D':'red', 'E':'blue', 'F':'green', 'G':'black'}

# # ax.scatter(df['carat'], df['price'], c=df['color'].apply(lambda x: colors[x]))

# %%
# tsne = TSNE(n_components = 2, n_iter = 1000, perplexity = 30)
# tsne_run = tsne.fit_transform(new_data)
# plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
# text(tsne_run, labels = rownames(dat))

# %%
#250 iterations
tsne = TSNE(n_components = 2, n_iter = 250, perplexity = 30)
tsne_run = tsne.fit_transform(new_data)
# plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
plt.ylabel('coord2')
plt.xlabel('coord1')
plt.plot(tsne_run)
plt.show()

# %%
#500 iterations
tsne = TSNE(n_components = 2, n_iter = 500, perplexity = 30)
tsne_run = tsne.fit_transform(new_data)
# plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
plt.ylabel('coord2')
plt.xlabel('coord1')
plt.plot(tsne_run)
plt.show()

# %%
#1000 iterations
tsne = TSNE(n_components = 2, n_iter = 1000, perplexity = 30)
tsne_run = tsne.fit_transform(new_data)
# plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
plt.ylabel('coord2')
plt.xlabel('coord1')
plt.plot(tsne_run)
plt.show()

# %%
#2000 iterations
tsne = TSNE(n_components = 2, n_iter = 2000, perplexity = 30)
tsne_run = tsne.fit_transform(new_data)
# plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
plt.ylabel('coord2')
plt.xlabel('coord1')
plt.plot(tsne_run)
plt.show()

# %%
#5000 iterations
tsne = TSNE(n_components = 2, n_iter = 5000, perplexity = 30)
tsne_run = tsne.fit_transform(new_data)
# plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
plt.ylabel('coord2')
plt.xlabel('coord1')
plt.plot(tsne_run)
plt.show()

# %%
#5 perplexity
tsne = TSNE(n_components = 2, n_iter = 5000, perplexity = 5)
tsne_run = tsne.fit_transform(new_data)
# plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
plt.ylabel('coord2')
plt.xlabel('coord1')
plt.plot(tsne_run)
plt.show()

# %%
#10 perplexity
tsne = TSNE(n_components = 2, n_iter = 5000, perplexity = 10)
tsne_run = tsne.fit_transform(new_data)
# plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
plt.ylabel('coord2')
plt.xlabel('coord1')
plt.plot(tsne_run)
plt.show()

# %%
#20 perplexity
tsne = TSNE(n_components = 2, n_iter = 5000, perplexity = 20)
tsne_run = tsne.fit_transform(new_data)
# plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
plt.ylabel('coord2')
plt.xlabel('coord1')
plt.plot(tsne_run)
plt.show()

# %%
#30 perplexity
tsne = TSNE(n_components = 2, n_iter = 5000, perplexity = 30)
tsne_run = tsne.fit_transform(new_data)
# plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
plt.ylabel('coord2')
plt.xlabel('coord1')
plt.plot(tsne_run)
plt.show()

# %%
#50 perplexity
tsne = TSNE(n_components = 2, n_iter = 5000, perplexity = 50)
tsne_run = tsne.fit_transform(new_data)
# plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
plt.ylabel('coord2')
plt.xlabel('coord1')
plt.plot(tsne_run)
plt.show()

# %%
#100 perplexity
tsne = TSNE(n_components = 2, n_iter = 5000, perplexity = 100)
tsne_run = tsne.fit_transform(new_data)
# plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
plt.ylabel('coord2')
plt.xlabel('coord1')
plt.plot(tsne_run)
plt.show()

# %%
#500 perplexity
tsne = TSNE(n_components = 2, n_iter = 5000, perplexity = 500)
tsne_run = tsne.fit_transform(new_data)
# plt.plot(tsne_run, t = 'n', main = "tSNE01", xlab = "coord1", ylab = "coord2")
plt.ylabel('coord2')
plt.xlabel('coord1')
plt.plot(tsne_run)
plt.show()
